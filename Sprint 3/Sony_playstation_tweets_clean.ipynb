# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('F:/lmu data/BSAN6080/final project/Sony_Playstation_tweets.csv')
# Out:
# F:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
display(data.head())
display(data.describe())
display(data.info())
display(data.isnull().sum())
display(data.size)
display(data.shape)
display(data.ndim)
# Out:
#                     id      conversation_id  \
# 0  1513571642882072585  1513417628202774528
# 1  1513571464871559174  1513565997218816006
# 2  1513571334084874240  1513571334084874240
# 3  1513571286651482114  1513492170136825861
# 4  1513571091838496771  1513561330615156737
#
#                                   created_at        date      time  timezone  \
# 0  2022-04-11 10:36:15 Pacific Daylight Time  2022-04-11  10:36:15      -700
# 1  2022-04-11 10:35:32 Pacific Daylight Time  2022-04-11  10:35:32      -700
# 2  2022-04-11 10:35:01 Pacific Daylight Time  2022-04-11  10:35:01      -700
# 3  2022-04-11 10:34:50 Pacific Daylight Time  2022-04-11  10:34:50      -700
# 4  2022-04-11 10:34:03 Pacific Daylight Time  2022-04-11  10:34:03      -700
#
#                user_id         username              name place  ... geo  \
# 0  1364020710218338304       suwalfnoor              نوري   NaN  ... NaN
# 1             22482867         bluenfld                 M   NaN  ... NaN
# ...

# %%
data = data.drop([ 'conversation_id',
'created_at',
'time',
'timezone',
'user_id',
'name',
'place',
'mentions',
'urls',
'photos',
'cashtags',
'link',
'retweet',
'quote_url',
'video',
'thumbnail',
'near',
'geo',
'source',
'user_rt_id',
'user_rt',
'retweet_id',
'reply_to',      
'retweet_date',    
'translate',          
'trans_src',          
'trans_dest'],axis = 1)

# %%
display(data.head())
display(data.describe())
display(data.info())
display(data.isnull().sum())
# Out:
#                     id        date         username  \
# 0  1513571642882072585  2022-04-11       suwalfnoor
# 1  1513571464871559174  2022-04-11         bluenfld
# 2  1513571334084874240  2022-04-11      darrenewers
# 3  1513571286651482114  2022-04-11  noobsiabotxsmo1
# 4  1513571091838496771  2022-04-11          lolkudo
#
#                                                tweet language  replies_count  \
# 0  @Hammodyy100120 @adaVP @AishaHakami9 @Dark_Sid...      und              0
# 1  @PNDKetchup @ultradavid @PlayStation Will you ...       en              0
# 2  Sony is the best video game maker in the world...       en              0
# 3  @GermanStrands The next @PlayStation showcase ...       en              0
# 4                    @rcats99 @PlayStation CONGRATS!       en              0
#
#    retweets_count  likes_count  \
# 0               0            0
# 1               0            0
# 2               0            1
# 3               0            0
# ...

# %%
data['tweet']
# Out:
# 0        @Hammodyy100120 @adaVP @AishaHakami9 @Dark_Sid...
# 1        @PNDKetchup @ultradavid @PlayStation Will you ...
# 2        Sony is the best video game maker in the world...
# 3        @GermanStrands The next @PlayStation showcase ...
# 4                          @rcats99 @PlayStation CONGRATS!
#                                ...
# 19413                                @PlayStation Purple 🔥
# 19414    Day 299 of asking @Sony @PlayStation and @herm...
# 19415    @Innthacut @kidsmoove @PlayStation Are you rea...
# 19416    @PlayStation To be honest once i can reach for...
# 19417    @TheViennri @lilley_ross @kidsmoove @PlayStati...
# Name: tweet, Length: 19418, dtype: object
