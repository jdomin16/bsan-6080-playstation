# %%
pip install nest_asyncio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint #importing twint package so we can webscrape tweets from twitter

# Configure
c = twint.Config()
c.Search = "Sony Playstation" #We are webscraping tweets from sony playstation
c.Lang = "english"
c.Limit = 1000000
c.Output = "./Sony_Playstation_tweets.csv" #Outputting tweets into a csv file
c.Store_csv = True

# Run
twint.run.Search(c) #Printing out the tweets we got from the webscrape
# Out:
# 1513571642882072585 2022-04-11 10:36:15 -0700 <suwalfnoor> @Hammodyy100120 @adaVP @AishaHakami9 @Dark_Side_l99l @PlayStation @Hamad_al7anoti @m5aoi @josothetaker99  https://t.co/qhmIwGdInl
# 1513571464871559174 2022-04-11 10:35:32 -0700 <BlueNFLD> @PNDKetchup @ultradavid @PlayStation Will you be commentating Evo this year?
# 1513571334084874240 2022-04-11 10:35:01 -0700 <DarrenEwers> Sony is the best video game maker in the world and the PS5 Bafta wins prove it – Reader’s Feature  https://t.co/N7RAK4hDRP #Sony #PlayStation #PlayStation5 #PS5 #gaming #GamingNews
# 1513571286651482114 2022-04-11 10:34:50 -0700 <noobsiabotxsmo1> @GermanStrands The next @PlayStation showcase better be GOW
# 1513571091838496771 2022-04-11 10:34:03 -0700 <LoLKudo> @rcats99 @PlayStation CONGRATS!
# 1513570963538923520 2022-04-11 10:33:33 -0700 <fesachu> @rcats99 @PlayStation congrats :D
# 1513570894114955269 2022-04-11 10:33:16 -0700 <jackhufstetler> @PlayStation bring back #TheBouncer
# ...

# %%
import pandas as pd #Importing pandas dataframe to manipulate and check the data file is formatted correctly
pd.options.display.max_columns = 100

# %%
data = pd.read_csv("./Sony_Playstation_tweets.csv", low_memory=False) #Loadinging large csv file with the tweets

# %%
data.shape
# Out:
# (19418, 36)

# %%
data.head() #Checking out what we got from the csv file
# Out:
#                     id      conversation_id  \
# 0  1513571642882072585  1513417628202774528
# 1  1513571464871559174  1513565997218816006
# 2  1513571334084874240  1513571334084874240
# 3  1513571286651482114  1513492170136825861
# 4  1513571091838496771  1513561330615156737
#
#                                   created_at        date      time  timezone  \
# 0  2022-04-11 10:36:15 Pacific Daylight Time  2022-04-11  10:36:15      -700
# 1  2022-04-11 10:35:32 Pacific Daylight Time  2022-04-11  10:35:32      -700
# 2  2022-04-11 10:35:01 Pacific Daylight Time  2022-04-11  10:35:01      -700
# 3  2022-04-11 10:34:50 Pacific Daylight Time  2022-04-11  10:34:50      -700
# 4  2022-04-11 10:34:03 Pacific Daylight Time  2022-04-11  10:34:03      -700
#
#                user_id         username              name place  \
# 0  1364020710218338304       suwalfnoor              نوري   NaN
# 1             22482867         bluenfld                 M   NaN
# ...
